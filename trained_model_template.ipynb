# %% [markdown]
# # Template For Load and Use a Pre-Trained Model
#
# I tried to create a template for you to reuse the models you have pre-trained with the transfer learning method. I hope this will be useful.
#
# ##### Kind regards,
#
# <table align="left">
# <td>Zorkan ERKAN</td>
# <td></td>
# <td><a target="_blank" href="https://www.tensorflow.org/tfx/tutorials/tfx/template">
# <img src="https://github.com/zorkan/generalfiles/blob/main/317750_linkedin_icon.png?raw=true" width=28px /></a></td>
# <td></td>
# <td><a target="_blank" href="https://github.com/zorkan">
# <img width=28px src="https://www.tensorflow.org/images/GitHub-Mark-32px.png"></a></td>
# </table>

# %% [markdown]
# # Trained Model Process
#
# ![image.png](data:image/png;base64,...)
# In the graphic above you can see the steps for using any trained and saved model.

# %% [markdown]
# ## Download Materials
#
#
# *   101_food_classes_10_percent.zip

# %%
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/101_food_classes_10_percent.zip

# %% [markdown]
# ## Data Preperation
#
# ![image.png](data:image/png;base64,...)
# Data Preperation includes these steps:
#
# 1.   Download and check image files
# 2.   Set paths
# 3.   Check class names from folder
# 4.   Get random images from classes

# %% [markdown]
# ### 1. Download and Check Image Files
#
# Firstly, I will download from url .zip file and extract to folder then I will check created files in the root folder.

# %% [markdown]
# ### 2. Setting Paths
#
# Set root, train and test paths to use in all project parts.

# %% [markdown]
# ### 3. Check Class Names
# Check class names from test directory

# %% [markdown]
# ### 4. Get Random Images
# Get random images from random class

# %% [markdown]
# ## Create Datasets
#
# ![image.png](data:image/png;base64,...)
# Create train and validation datasets
#
# *   Train and validation dataset

# %% [markdown]
# ### Train and Validation Datasets
# Create train and validation datasets, get class names from validation dataset and print shape batch datas.

# %% [markdown]
# ## Load Model
#
# ![image.png](data:image/png;base64,...)
#
# Load trained model from directory
#
# 1.   Model Loading
# 2.   Model Evaluating

# %% [markdown]
# ### Model Loading
# download or import from directory and create model.

# %% [markdown]
# ### Model Evaluating
# Get loss and accuracy values from model with validation datas.

# %% [markdown]
# ## Model Prediction
# ![image.png](data:image/png;base64,...)
# Model prediction and get y_pred values.
#
# 1.   Model Predict
# 2.   y_pred labels
# 3.   y_true labels

# %% [markdown]
# ### Model Predict
# Make validation data predictions and get info's.

# %% [markdown]
# ### y_pred labels
# Get y_pred values from predicted data

# %% [markdown]
# ### y_true labels
# Get y_true values from validation datas

# %% [markdown]
# ## Evaluating models predictions
# ![image.png](data:image/png;base64,...)
# Evaluate model prediction and visualize
#
# 1.   Get Accuracy Score
# 2.   Compare Accuracies
# 3.   Show Confusion Matrix Table

# %% [markdown]
# ### Evaluate model and compare accuracy
# Get accuracy score from sklearn metrics

# %% [markdown]
# ### Get confusion matrix for classes
# Use helper functions from drive folder

# %% [markdown]
# ## Get Classification Report
# ![image.png](data:image/png;base64,...)
# Get classification report and visualize
#
# 1.   Get classification metrics as dictionary
# 2.   Get F1 scores from classification
# 3.   F1 scores visualize

# %% [markdown]
# ### Get classification values as dictionary
# Get dict classification report

# %% [markdown]
# ### Get F1 scores from classification
# Get F1 Scores from classification as dictionary

# %% [markdown]
# ### F1 Scores Visualize
# Convert dataframe f1_scores_dict values and visualize horizontal bar chart.

# %% [markdown]
# # Model Test
# ![image.png](data:image/png;base64,...)
# In the graphic above you can see the steps for testing any model.

# %% [markdown]
# ## Create Image Preperation Method
# ![image.png](data:image/png;base64,...)
#
# Create preparation function for all image test process.

# %% [markdown]
# ## Prediction Test From Random Class
# ![image.png](data:image/png;base64,...)
# Take the Random Class Prediction Test.

# %% [markdown]
# ## Preperation image paths from Validation folder
# ![image.png](data:image/png;base64,...)
# Get all image paths from verification folder.

# %% [markdown]
# ## Create Validation Data Frame
# ![image.png](data:image/png;base64,...)
#
# Create Verification Data Framework for detailed data.

# %% [markdown]
# ## Show Correct Classes
# ![image.png](data:image/png;base64,...)
#
# Create a correction column with True or False values.

# %% [markdown]
# ## Get Most Wrong Classes
# ![image.png](data:image/png;base64,...)
#
# Get most wrong classes for visualize.

# %% [markdown]
# ## Visually Check Wrong Classes
# ![image.png](data:image/png;base64,...)
#
# Wrong classes visualizing.

# %% [markdown]
# # Real Test Process
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/custom_food_images.zip

# %% [markdown]
# ## Get File Paths
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Predict And Show Results
# ![image.png](data:image/png;base64,...)
